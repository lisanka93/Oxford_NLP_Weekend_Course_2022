# %% [markdown]
# # Introduction to Text Anaysis and Natural Language Processing (in Python)
#
# ### Content for the first hour
# - Who I am and what I do
# - What NLP is and its application
# - Intro to Google Colab (for those who do not have another coding environment on their machine)

# %% [markdown]
# ## Lisa Andreevna Chalaguine
# ![me2.png](attachment:me2.png)
#
# - did my PhD at University College London (currently writing up my thesis) in the Intelligent Systems Group
# - developed chatbots that can engage in argumentative dialogues with people (e.g. convincing them to get a COVID-19 vaccine)
# - since October working as an NLP Data Scientiest in a small startup in the LegalTech domain (dealing with UK and EU Regulations)
# - still doing a lot of teaching on the side (mentoring high-school kids, helping university students with ML courseworks, and here at Oxford Uni)

# %% [markdown]
# ## What is NLP
# ![Screenshot%20from%202022-03-08%2016-34-18.png](attachment:Screenshot%20from%202022-03-08%2016-34-18.png)

# %% [markdown]
# - Field of AI that gives machines the ability to read, understand and derive meaning from human language
# - Not just string processing and keyword matching
# - NLP combines computational linguistics—rule-based modeling of human language—with statistical, machine learning, and deep learning models. Together, these technologies enable computers to process human language in the form of text or voice data and to ‘understand’ its full meaning, complete with the speaker or writer’s intent and sentiment

# %% [markdown]
# ## Applications of NLP

# %% [markdown]
# ● Machine Translation (e.g. Google Translate
#
# ● Virtual Assistants (Siri, Alexa etc.)
#
# ● Information Extraction
#
# ● Summarisation
#
# ● Text Generation
#
# ● Question Answering
#
# ● Text Generation
#
# ● Sentiment Analysis
#
# ● Text Classification
#
# ● Auto Correct

# %% [markdown]
# ![Screenshot%20from%202022-03-08%2016-47-09.png](attachment:Screenshot%20from%202022-03-08%2016-47-09.png)

# %% [markdown]
# ## Challenges
#
#
# ● Unstructured data
#
# ● Ambiguity (lexial and structural)
#
# ● Synonyms
#
# ● Anaphora
#
# ● Sarcasm
#
# ● Coreference

# %% [markdown]
# ![Screenshot%202022-03-08%20at%2016-45-22%20dumpling%20tuxedo%20-%20Google%20Search.png](attachment:Screenshot%202022-03-08%20at%2016-45-22%20dumpling%20tuxedo%20-%20Google%20Search.png)

# %% [markdown]
# ### Lexical Ambiguity
#
# Same words, different meaning (homographs)
#
# ![Screenshot%202022-03-08%20at%2017-03-13%20homographs%20-%20Google%20Search.png](attachment:Screenshot%202022-03-08%20at%2017-03-13%20homographs%20-%20Google%20Search.png)

# %% [markdown]
# ### Structural Ambiguity
#
# ![Screenshot%20from%202022-03-08%2016-48-23.png](attachment:Screenshot%20from%202022-03-08%2016-48-23.png)
#
# #### Ambiguity Game: http://madlyambiguous.osu.edu/

# %% [markdown]
# ### Synonymy
#
# Same mearning, different words

# %% [markdown]
# ![Screenshot%202022-03-08%20at%2016-54-36%20google%20translate%20putin%20-%20Google%20Search.png](attachment:Screenshot%202022-03-08%20at%2016-54-36%20google%20translate%20putin%20-%20Google%20Search.png)
#
# #### Machine Reading: https://demo.allennlp.org/reading-comprehension/bidaf-elmo

# %% [markdown]
# ### Language Change
#
# Language constantly changes
#
# #### Googles n-gram viewer: https://books.google.com/ngrams

# %% [markdown]
# ### Figurative Speech
#
# Ordinary sentences refering to something without explicitly stating it (metaphors, irony, sarcasm, hyperboles etc.)
#
# #### sentiment analysis: https://demo.allennlp.org/sentiment-analysis/glove-sentiment-analysis
